# %%
import torch
import numpy
import sklearn
import pprint
import torchvision
import sklearn
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay
import torch
import torchvision
import random
import numpy as np
import matplotlib
import matplotlib.pyplot as plt
import torchvision.models as model
import torchvision.transforms as transforms
from torch.utils.data import Dataset, DataLoader
import torch.nn.functional as F
import torch.utils.model_zoo as model_zoo
import tarfile
import shutil
from torch.nn import DataParallel
from pathlib import Path
from PIL import Image
import cv2
import os
from retinaface import RetinaFace
from deepface import DeepFace
import torch.nn as nn
from PIL import Image
import math
import time
import lightning as L
from models.deepheadpose.code.hopenet import Hopenet
from models.deepheadpose.code.utils import softmax_temperature
from typing import Any
from lightning.pytorch.utilities.types import TRAIN_DATALOADERS
from pytorch_lightning.utilities.types import STEP_OUTPUT
from pytorch_lightning.tuner import Tuner
from torch import Tensor
from models.resnet50 import iresnet50

# %%
# !nvidia-smi
# Out:
# Fri Nov  3 14:34:00 2023
# +-----------------------------------------------------------------------------+
# | NVIDIA-SMI 525.147.05   Driver Version: 525.147.05   CUDA Version: 12.0     |
# |-------------------------------+----------------------+----------------------+
# | GPU  Name        Persistence-M| Bus-Id        Disp.A | Volatile Uncorr. ECC |
# | Fan  Temp  Perf  Pwr:Usage/Cap|         Memory-Usage | GPU-Util  Compute M. |
# |                               |                      |               MIG M. |
# |===============================+======================+======================|
# |   0  NVIDIA GeForce ...  Off  | 00000000:01:00.0  On |                  N/A |
# | 23%   27C    P8     9W / 250W |     47MiB / 11264MiB |      0%      Default |
# |                               |                      |                  N/A |
# +-------------------------------+----------------------+----------------------+
#
# +-----------------------------------------------------------------------------+
# | Processes:                                                                  |
# |  GPU   GI   CI        PID   Type   Process name                  GPU Memory |
# |        ID   ID                                                   Usage      |
# |=============================================================================|
# |    0   N/A  N/A      1205      G   /usr/lib/xorg/Xorg                 36MiB |
# |    0   N/A  N/A      1449      G   /usr/bin/gnome-shell                7MiB |
# +-----------------------------------------------------------------------------+

# %%
device = torch.device("cuda")
ones = torch.ones(1, device= device)
if torch.cuda:
    mps_device = torch.device("cuda")
    x = torch.ones(1, device=mps_device)
    print (x)
else:
    print ("cuda device not found.")
# Out:
# tensor([1.], device='cuda:0')

# %%
class FocalLoss(torch.nn.Module):
    def __init__(self, weight=None, gamma=0, eps=1e-7):
        super(FocalLoss, self).__init__()
        self.gamma = gamma
        self.eps = eps
        self.ce = torch.nn.CrossEntropyLoss(weight=weight)

    def forward(self, input, target):
        logp = self.ce(input, target)
        p = torch.exp(-logp)
        loss = (1 - p) ** self.gamma * logp
        return loss.mean()

# %%
class ArcFaceLoss(torch.nn.Module):
    """Implement of large margin arc distance: :
        Args:
            in_features: size of each input sample
            out_features: size of each output sample
            s: norm of input feature
            m: margin

            cos(theta + m)
        """
    def __init__(self, in_features, out_features, s=30.0, m=0.50):
        super(ArcFaceLoss, self).__init__()
        self.in_features = in_features
        self.out_features = out_features
        self.s = s
        self.m = m
        self.weight = torch.nn.Parameter(torch.FloatTensor(out_features, in_features))
        torch.nn.init.xavier_uniform_(self.weight)

        self.cos_m = math.cos(m)
        self.sin_m = math.sin(m)
        self.th = math.cos(math.pi - m)
        self.mm = math.sin(math.pi - m) * m

    def forward(self, feature, label= None):
        # Normalize embeddings and weights
        feature = F.normalize(feature)
        weights = F.normalize(self.weight)

        # Compute the logit
        cos_theta = F.linear(feature, weights)
        
        if (label is None):
            return cos_theta

        # Find the angle between the weight and feature
        theta = torch.acos(cos_theta)

        # Add angular margin penalty
        marginal_target_logit = torch.cos(theta + self.m)
        
        marginal_target_logit = torch.where(cos_theta > self.th, marginal_target_logit, cos_theta - self.mm)

        # One-hot encoding
        one_hot = torch.zeros(cos_theta.size(), device=device)
       # one_hot = torch.zeros_like(cos_theta)
        one_hot.scatter_(1, label.view(-1, 1).long(), 1)

        # Compute class wise similarity score through element wise multiplication of one_hot ground truth and the marginal target logit
        score = (one_hot * marginal_target_logit) + ((1.0 - one_hot) * cos_theta)
        #score = torch.mul(marginal_target_logit, one_hot)

        # Rescale to s
        score *= self.s

        return score

# %%
# transform into tensors
transform_train = transforms.Compose([
    transforms.RandomHorizontalFlip(),
    transforms.RandomResizedCrop((112,112)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

transform = transforms.Compose([
    transforms.Resize((112, 112)),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

transform_pose = transforms.Compose([
    transforms.Resize((224, 224)),
    transforms.CenterCrop(224),
    transforms.ToTensor(),
    transforms.Normalize([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])
])

# %%
def make_folders(img_dir):
    # Set the root directory path where the subdirectories are located
    # Loop through each file in the directory
    for filename in os.listdir(img_dir):
        
        # Check if the file is a .ppm image
        if filename.endswith('.jpg'):
            
            # Get the person's name from the filename
            name = filename.split('_')[:-1]
            name = '_'.join(name)
            
            # Create a directory for the person if it doesn't exist
            if not os.path.exists(os.path.join(img_dir, name)):
                os.makedirs(os.path.join(img_dir, name))
            
            # Open the image and save it as a .jpeg in the person's directory
            img = Image.open(os.path.join(img_dir, filename))
            img.save(os.path.join(img_dir, name, filename.replace('.jpg', '.jpg')))
make_folders("./cplfw/aligned images/")

# %%
# Set your dataset directory path here
def MakeFoldersTrainTest(dataset_dir, dist_dir):
    # Set your train, val, and test ratios here
    train_ratio = 0.8
    test_ratio = 0.2

    # Get the list of subdirectories in the dataset directory
    subdirs = [name for name in os.listdir(dataset_dir) if os.path.isdir(os.path.join(dataset_dir, name))]

    # Shuffle the list of subdirectories
    random.shuffle(subdirs)

    # Split the subdirectories into train, val, and test sets
    train_subdirs = subdirs[:int(len(subdirs) * train_ratio)]
    test_subdirs = subdirs[int(len(subdirs) * (train_ratio)):]

    # Create the train, val, and test directories
    train_dir = os.path.join(dist_dir, "HELEN_train")
    os.makedirs(train_dir, exist_ok=True)
    test_dir = os.path.join(dist_dir, "HELEN_test")
    os.makedirs(test_dir, exist_ok=True)

    # Move the images from the subdirectories to the train, val, and test directories
    for subdir in train_subdirs:
        src_dir = os.path.join(dataset_dir, subdir)
        dst_dir = os.path.join(train_dir, subdir)
        os.makedirs(dst_dir, exist_ok=True)
        for img_file in os.listdir(src_dir):
            src_path = os.path.join(src_dir, img_file)
            dst_path = os.path.join(dst_dir, img_file)
            shutil.copy(src_path, dst_path)

    for subdir in test_subdirs:
        src_dir = os.path.join(dataset_dir, subdir)
        dst_dir = os.path.join(test_dir, subdir)
        os.makedirs(dst_dir, exist_ok=True)
        for img_file in os.listdir(src_dir):
            src_path = os.path.join(src_dir, img_file)
            dst_path = os.path.join(dst_dir, img_file)
            shutil.copy(src_path, dst_path)
dataset_dir = "./data/300WLPA_2d/HELEN_detected/"
MakeFoldersTrainTest(dataset_dir=dataset_dir, dist_dir= './data/300WLPA_2d/')

# %%
import pickle

with open('data/pickles/helen_train.pkl', 'rb') as f:
    content = pickle.load(f)
    
content
# Out:
# [{'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_7_-0.752_0.798_0.075.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_1_-0.407_0.275_0.084.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_15_-0.226_1.496_0.089.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_12_-0.467_1.235_0.089.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_11_-0.230_1.147_0.080.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_2_-0.760_0.362_0.078.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_2_-0.411_0.362_0.078.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_6_-0.696_0.711_0.079.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_0_-0.571_0.188_0.067.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_5_-0.326_0.624_0.069.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_3_-0.764_0.449_0.097.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_11_-0.405_1.147_0.080.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_1_-0.320_0.275_0.084.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_15_-0.488_1.496_0.089.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_15_-0.313_1.496_0.089.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_2_-0.673_0.362_0.078.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_6_-0.783_0.711_0.079.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_5_-0.675_0.624_0.069.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_1_-0.756_0.275_0.084.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_9_-0.285_0.973_0.083.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_15_-0.400_1.496_0.089.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_7_-0.664_0.798_0.075.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_12_-0.293_1.235_0.089.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_0_-0.745_0.188_0.067.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_0_-0.222_0.188_0.067.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_8_-0.588_0.886_0.070.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_13_-0.474_1.322_0.101.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_10_-0.664_1.060_0.071.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_8_-0.327_0.886_0.070.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_14_-0.317_1.409_0.083.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_7_-0.228_0.798_0.075.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_3_-0.328_0.449_0.097.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_11_-0.492_1.147_0.080.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_0_-0.483_0.188_0.067.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_9_-0.372_0.973_0.083.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_0_-0.658_0.188_0.067.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_2_-0.585_0.362_0.078.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_8_-0.501_0.886_0.070.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_8_-0.676_0.886_0.070.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_11_-0.667_1.147_0.080.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_5_-0.587_0.624_0.069.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_9_-0.722_0.973_0.083.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_3_-0.415_0.449_0.097.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_3_-0.502_0.449_0.097.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_12_-0.380_1.235_0.089.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_7_-0.315_0.798_0.075.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_10_-0.577_1.060_0.071.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_6_-0.609_0.711_0.079.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_10_-0.752_1.060_0.071.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_9_-0.634_0.973_0.083.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_4_-0.620_0.537_0.096.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_14_-0.230_1.409_0.083.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_12_-0.555_1.235_0.089.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_10_-0.490_1.060_0.071.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_5_-0.413_0.624_0.069.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_7_-0.577_0.798_0.075.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_11_-0.579_1.147_0.080.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_10_-0.403_1.060_0.071.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_15_-0.575_1.496_0.089.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_5_-0.500_0.624_0.069.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_11_-0.754_1.147_0.080.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_6_-0.347_0.711_0.079.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_5_-0.762_0.624_0.069.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_6_-0.260_0.711_0.079.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_14_-0.666_1.409_0.083.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_8_-0.763_0.886_0.070.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_14_-0.492_1.409_0.083.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_7_-0.403_0.798_0.075.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_2_-0.324_0.362_0.078.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_2_-0.498_0.362_0.078.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_4_-0.533_0.537_0.096.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_11_-0.318_1.147_0.080.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_1_-0.581_0.275_0.084.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_13_-0.387_1.322_0.101.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_15_-0.662_1.496_0.089.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_6_-0.434_0.711_0.079.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_12_-0.642_1.235_0.089.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_3_-0.677_0.449_0.097.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_13_-0.561_1.322_0.101.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_9_-0.547_0.973_0.083.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_3_-0.589_0.449_0.097.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_10_-0.315_1.060_0.071.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_6_-0.521_0.711_0.079.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_1_-0.669_0.275_0.084.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_1_-0.494_0.275_0.084.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_14_-0.404_1.409_0.083.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_4_-0.271_0.537_0.096.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_12_-0.729_1.235_0.089.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_3_-0.240_0.449_0.097.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_4_-0.446_0.537_0.096.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_13_-0.649_1.322_0.101.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_4_-0.358_0.537_0.096.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_13_-0.300_1.322_0.101.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_14_-0.579_1.409_0.083.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_5_-0.238_0.624_0.069.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_13_-0.736_1.322_0.101.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_4_-0.708_0.537_0.096.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_10_-0.228_1.060_0.071.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_0_-0.309_0.188_0.067.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_9_-0.460_0.973_0.083.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_7_-0.490_0.798_0.075.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_0_-0.396_0.188_0.067.jpg'},
#  {'id': 2700468932,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2700468932/HELEN_2700468932_1_8_-0.414_0.886_0.070.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_6_-0.629_0.923_-0.116.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_12_-0.722_1.447_-0.084.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_11_-0.542_1.359_-0.110.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_4_-0.756_0.748_-0.105.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_8_-0.191_1.098_-0.092.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_13_-0.204_1.534_-0.098.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_7_-0.213_1.010_-0.088.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_4_-0.407_0.748_-0.105.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_2_-0.277_0.574_-0.107.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_11_-0.106_1.359_-0.110.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_9_-0.454_1.185_-0.117.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_12_-0.286_1.447_-0.084.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_4_-0.669_0.748_-0.105.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_0_-0.536_0.399_-0.081.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_10_-0.143_1.272_-0.093.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_1_-0.549_0.487_-0.115.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_8_-0.453_1.098_-0.092.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_12_-0.373_1.447_-0.084.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_6_-0.368_0.923_-0.116.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_11_-0.193_1.359_-0.110.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_11_-0.367_1.359_-0.110.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_10_-0.492_1.272_-0.093.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_13_-0.379_1.534_-0.098.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_2_-0.190_0.574_-0.107.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_9_-0.105_1.185_-0.117.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_5_-0.276_0.836_-0.082.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_2_-0.539_0.574_-0.107.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_8_-0.540_1.098_-0.092.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_13_-0.466_1.534_-0.098.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_11_-0.455_1.359_-0.110.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_10_-0.666_1.272_-0.093.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_9_-0.628_1.185_-0.117.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_3_-0.318_0.661_-0.086.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_6_-0.280_0.923_-0.116.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_2_-0.626_0.574_-0.107.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_11_-0.629_1.359_-0.110.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_5_-0.189_0.836_-0.082.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_9_-0.715_1.185_-0.117.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_10_-0.404_1.272_-0.093.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_0_-0.274_0.399_-0.081.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_7_-0.737_1.010_-0.088.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_12_-0.199_1.447_-0.084.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_6_-0.542_0.923_-0.116.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_12_-0.635_1.447_-0.084.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_7_-0.300_1.010_-0.088.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_10_-0.317_1.272_-0.093.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_12_-0.461_1.447_-0.084.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_1_-0.724_0.487_-0.115.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_9_-0.541_1.185_-0.117.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_11_-0.280_1.359_-0.110.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_1_-0.200_0.487_-0.115.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_5_-0.538_0.836_-0.082.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_3_-0.405_0.661_-0.086.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_4_-0.145_0.748_-0.105.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_7_-0.649_1.010_-0.088.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_13_-0.728_1.534_-0.098.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_8_-0.715_1.098_-0.092.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_13_-0.117_1.534_-0.098.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_7_-0.126_1.010_-0.088.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_7_-0.475_1.010_-0.088.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_13_-0.554_1.534_-0.098.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_2_-0.365_0.574_-0.107.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_3_-0.492_0.661_-0.086.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_8_-0.278_1.098_-0.092.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_1_-0.288_0.487_-0.115.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_0_-0.710_0.399_-0.081.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_6_-0.106_0.923_-0.116.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_13_-0.292_1.534_-0.098.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_4_-0.582_0.748_-0.105.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_6_-0.455_0.923_-0.116.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_0_-0.361_0.399_-0.081.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_1_-0.113_0.487_-0.115.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_7_-0.387_1.010_-0.088.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_0_-0.449_0.399_-0.081.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_5_-0.364_0.836_-0.082.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_10_-0.579_1.272_-0.093.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_9_-0.192_1.185_-0.117.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_6_-0.717_0.923_-0.116.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_5_-0.713_0.836_-0.082.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_0_-0.623_0.399_-0.081.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_3_-0.231_0.661_-0.086.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_10_-0.230_1.272_-0.093.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_8_-0.104_1.098_-0.092.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_8_-0.365_1.098_-0.092.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_6_-0.193_0.923_-0.116.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_3_-0.143_0.661_-0.086.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_1_-0.375_0.487_-0.115.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_4_-0.494_0.748_-0.105.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_4_-0.320_0.748_-0.105.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_3_-0.754_0.661_-0.086.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_13_-0.641_1.534_-0.098.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_1_-0.462_0.487_-0.115.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_4_-0.233_0.748_-0.105.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_12_-0.112_1.447_-0.084.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_3_-0.667_0.661_-0.086.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_3_-0.580_0.661_-0.086.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_0_-0.187_0.399_-0.081.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_5_-0.625_0.836_-0.082.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_9_-0.366_1.185_-0.117.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_12_-0.548_1.447_-0.084.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_7_-0.562_1.010_-0.088.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_8_-0.627_1.098_-0.092.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_10_-0.753_1.272_-0.093.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_2_-0.103_0.574_-0.107.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_9_-0.279_1.185_-0.117.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_1_-0.637_0.487_-0.115.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_11_-0.716_1.359_-0.110.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_0_-0.100_0.399_-0.081.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_2_-0.452_0.574_-0.107.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_2_-0.714_0.574_-0.107.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_5_-0.102_0.836_-0.082.jpg'},
#  {'id': 2344217511,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2344217511/HELEN_2344217511_1_5_-0.451_0.836_-0.082.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_0_-0.584_0.395_0.018.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_1_-0.221_0.482_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_8_-0.510_1.093_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_13_-0.444_1.529_0.027.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_13_-0.183_1.529_0.027.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_2_-0.621_0.569_0.025.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_4_-0.164_0.744_0.021.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_0_-0.758_0.395_0.018.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_6_-0.655_0.918_0.020.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_3_-0.720_0.657_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_11_-0.197_1.355_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_4_-0.425_0.744_0.021.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_7_-0.481_1.006_0.023.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_8_-0.423_1.093_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_8_-0.248_1.093_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_4_-0.687_0.744_0.021.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_11_-0.634_1.355_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_5_-0.347_0.831_0.026.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_8_-0.597_1.093_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_2_-0.534_0.569_0.025.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_4_-0.338_0.744_0.021.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_3_-0.546_0.657_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_3_-0.284_0.657_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_9_-0.156_1.180_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_5_-0.522_0.831_0.026.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_0_-0.322_0.395_0.018.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_6_-0.568_0.918_0.020.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_5_-0.784_0.831_0.026.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_0_-0.409_0.395_0.018.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_12_-0.774_1.442_0.019.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_1_-0.395_0.482_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_2_-0.708_0.569_0.025.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_1_-0.308_0.482_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_9_-0.418_1.180_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_9_-0.593_1.180_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_6_-0.393_0.918_0.020.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_12_-0.163_1.442_0.019.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_10_-0.552_1.268_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_3_-0.459_0.657_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_8_-0.161_1.093_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_6_-0.481_0.918_0.020.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_2_-0.359_0.569_0.025.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_1_-0.744_0.482_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_10_-0.378_1.268_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_1_-0.570_0.482_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_1_-0.657_0.482_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_3_-0.633_0.657_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_6_-0.306_0.918_0.020.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_0_-0.496_0.395_0.018.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_9_-0.767_1.180_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_10_-0.639_1.268_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_11_-0.372_1.355_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_0_-0.671_0.395_0.018.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_8_-0.335_1.093_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_5_-0.434_0.831_0.026.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_7_-0.743_1.006_0.023.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_0_-0.147_0.395_0.018.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_6_-0.219_0.918_0.020.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_11_-0.285_1.355_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_9_-0.331_1.180_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_13_-0.357_1.529_0.027.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_4_-0.600_0.744_0.021.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_7_-0.393_1.006_0.023.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_4_-0.251_0.744_0.021.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_2_-0.272_0.569_0.025.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_7_-0.655_1.006_0.023.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_11_-0.547_1.355_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_10_-0.203_1.268_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_12_-0.599_1.442_0.019.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_12_-0.250_1.442_0.019.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_13_-0.532_1.529_0.027.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_0_-0.234_0.395_0.018.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_12_-0.425_1.442_0.019.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_13_-0.706_1.529_0.027.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_10_-0.290_1.268_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_5_-0.260_0.831_0.026.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_4_-0.774_0.744_0.021.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_6_-0.743_0.918_0.020.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_10_-0.465_1.268_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_9_-0.680_1.180_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_12_-0.337_1.442_0.019.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_13_-0.619_1.529_0.027.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_12_-0.686_1.442_0.019.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_7_-0.568_1.006_0.023.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_4_-0.513_0.744_0.021.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_5_-0.609_0.831_0.026.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_7_-0.219_1.006_0.023.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_11_-0.721_1.355_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_8_-0.685_1.093_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_3_-0.197_0.657_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_1_-0.482_0.482_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_13_-0.270_1.529_0.027.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_8_-0.772_1.093_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_2_-0.446_0.569_0.025.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_9_-0.244_1.180_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_9_-0.505_1.180_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_11_-0.459_1.355_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_3_-0.371_0.657_0.024.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_5_-0.696_0.831_0.026.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_12_-0.512_1.442_0.019.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_10_-0.727_1.268_0.022.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_2_-0.185_0.569_0.025.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_5_-0.173_0.831_0.026.jpg'},
#  {'id': 2140513376,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2140513376/HELEN_2140513376_1_7_-0.306_1.006_0.023.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_9_-0.548_-0.797_0.019.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_16_-0.471_-1.407_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_1_-0.554_-0.098_0.014.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_16_-0.646_-1.407_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_12_-0.286_-1.058_0.018.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_13_-0.189_-1.146_0.020.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_17_-0.124_-1.495_0.019.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_13_-0.538_-1.146_0.020.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_8_-0.392_-0.709_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_9_-0.460_-0.797_0.019.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_7_-0.379_-0.622_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_14_-0.125_-1.233_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_0_-0.440_-0.011_0.014.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_15_-0.215_-1.320_0.017.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_4_-0.534_-0.360_0.017.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_2_-0.470_-0.186_0.019.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_6_-0.547_-0.535_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_12_-0.635_-1.058_0.018.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_10_-0.458_-0.884_0.015.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_7_-0.205_-0.622_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_7_-0.117_-0.622_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_0_-0.528_-0.011_0.014.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_13_-0.713_-1.146_0.020.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_9_-0.286_-0.797_0.019.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_12_-0.722_-1.058_0.018.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_9_-0.722_-0.797_0.019.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_16_-0.209_-1.407_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_12_-0.460_-1.058_0.018.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_8_-0.479_-0.709_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_7_-0.292_-0.622_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_16_-0.384_-1.407_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_11_-0.284_-0.971_0.015.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_16_-0.558_-1.407_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_13_-0.276_-1.146_0.020.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_1_-0.729_-0.098_0.014.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_3_-0.567_-0.273_0.014.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_17_-0.648_-1.495_0.019.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_15_-0.477_-1.320_0.017.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_3_-0.480_-0.273_0.014.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_13_-0.625_-1.146_0.020.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_1_-0.118_-0.098_0.014.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_15_-0.390_-1.320_0.017.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_11_-0.196_-0.971_0.015.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_3_-0.305_-0.273_0.014.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_9_-0.373_-0.797_0.019.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_14_-0.386_-1.233_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_15_-0.565_-1.320_0.017.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_10_-0.720_-0.884_0.015.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_5_-0.102_-0.448_0.019.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_5_-0.451_-0.448_0.019.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_15_-0.303_-1.320_0.017.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_13_-0.451_-1.146_0.020.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_6_-0.634_-0.535_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_14_-0.299_-1.233_0.016.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_11_-0.371_-0.971_0.015.jpg'},
#  {'id': 2216370944,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2216370944/HELEN_2216370944_1_1_-0.467_-0.098_0.014.jpg'},
#  {'id': 2216370944,
# ...
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_3_0.741_0.629_-0.145.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_6_0.254_0.891_-0.161.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_8_0.354_1.066_-0.131.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_10_0.277_1.240_-0.147.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_9_0.381_1.153_-0.159.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_2_0.393_0.542_-0.135.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_11_0.757_1.327_-0.132.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_2_0.568_0.542_-0.135.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_13_0.575_1.502_-0.116.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_9_0.294_1.153_-0.159.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_0_0.332_0.367_-0.109.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_13_0.662_1.502_-0.116.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_6_0.341_0.891_-0.161.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_7_0.747_0.978_-0.112.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_4_0.671_0.716_-0.115.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_4_0.321_0.716_-0.115.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_0_0.768_0.367_-0.109.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_3_0.566_0.629_-0.145.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_12_0.207_1.415_-0.158.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_1_0.197_0.455_-0.157.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_5_0.313_0.804_-0.139.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_5_0.575_0.804_-0.139.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_10_0.714_1.240_-0.147.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_1_0.633_0.455_-0.157.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_13_0.226_1.502_-0.116.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_8_0.266_1.066_-0.131.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_6_0.603_0.891_-0.161.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_9_0.468_1.153_-0.159.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_12_0.556_1.415_-0.158.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_7_0.311_0.978_-0.112.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_8_0.528_1.066_-0.131.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_1_0.284_0.455_-0.157.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_11_0.670_1.327_-0.132.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_8_0.179_1.066_-0.131.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_10_0.190_1.240_-0.147.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_10_0.452_1.240_-0.147.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_12_0.731_1.415_-0.158.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_5_0.662_0.804_-0.139.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_4_0.234_0.716_-0.115.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_10_0.539_1.240_-0.147.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_7_0.660_0.978_-0.112.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_0_0.419_0.367_-0.109.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_5_0.400_0.804_-0.139.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_13_0.488_1.502_-0.116.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_7_0.485_0.978_-0.112.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_4_0.409_0.716_-0.115.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_4_0.583_0.716_-0.115.jpg'},
#  {'id': 153057847,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_153057847/HELEN_153057847_1_7_0.398_0.978_-0.112.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_12_-0.736_1.153_0.040.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_8_-0.204_0.804_0.041.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_5_-0.458_0.542_0.039.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_10_-0.521_0.978_0.031.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_2_-0.198_0.280_0.036.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_7_-0.512_0.717_0.031.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_4_-0.602_0.455_0.034.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_15_-0.234_1.415_0.041.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_2_-0.459_0.280_0.036.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_14_-0.287_1.328_0.030.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_14_-0.200_1.328_0.030.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_10_-0.608_0.978_0.031.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_10_-0.433_0.978_0.031.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_1_-0.454_0.193_0.037.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_16_-0.457_1.502_0.042.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_7_-0.250_0.717_0.031.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_1_-0.367_0.193_0.037.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_3_-0.511_0.368_0.035.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_3_-0.249_0.368_0.035.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_16_-0.283_1.502_0.042.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_3_-0.773_0.368_0.035.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_7_-0.686_0.717_0.031.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_14_-0.549_1.328_0.030.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_10_-0.783_0.978_0.031.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_16_-0.632_1.502_0.042.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_8_-0.378_0.804_0.041.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_9_-0.456_0.891_0.035.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_6_-0.450_0.629_0.030.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_13_-0.294_1.240_0.043.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_16_-0.544_1.502_0.042.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_11_-0.326_1.066_0.032.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_11_-0.763_1.066_0.032.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_0_-0.495_0.106_0.029.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_9_-0.194_0.891_0.035.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_2_-0.721_0.280_0.036.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_0_-0.320_0.106_0.029.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_12_-0.561_1.153_0.040.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_14_-0.462_1.328_0.030.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_11_-0.239_1.066_0.032.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_2_-0.547_0.280_0.036.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_5_-0.283_0.542_0.039.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_7_-0.599_0.717_0.031.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_6_-0.538_0.629_0.030.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_0_-0.582_0.106_0.029.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_2_-0.285_0.280_0.036.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_13_-0.207_1.240_0.043.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_4_-0.689_0.455_0.034.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_15_-0.322_1.415_0.041.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_4_-0.428_0.455_0.034.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_8_-0.291_0.804_0.041.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_2_-0.634_0.280_0.036.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_16_-0.195_1.502_0.042.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_16_-0.719_1.502_0.042.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_11_-0.152_1.066_0.032.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_11_-0.501_1.066_0.032.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_13_-0.644_1.240_0.043.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_1_-0.541_0.193_0.037.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_14_-0.636_1.328_0.030.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_3_-0.424_0.368_0.035.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_4_-0.253_0.455_0.034.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_3_-0.598_0.368_0.035.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_0_-0.145_0.106_0.029.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_9_-0.282_0.891_0.035.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_10_-0.259_0.978_0.031.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_12_-0.474_1.153_0.040.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_4_-0.166_0.455_0.034.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_15_-0.583_1.415_0.041.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_3_-0.336_0.368_0.035.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_10_-0.695_0.978_0.031.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_9_-0.369_0.891_0.035.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_12_-0.300_1.153_0.040.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_14_-0.374_1.328_0.030.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_14_-0.724_1.328_0.030.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_12_-0.212_1.153_0.040.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_8_-0.553_0.804_0.041.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_1_-0.192_0.193_0.037.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_8_-0.728_0.804_0.041.jpg'},
#  {'id': 2416614295,
#   'img_path': 'data/300WLPA_2d/HELEN_train/HELEN_2416614295/HELEN_2416614295_1_5_-0.196_0.542_0.039.jpg'},
#  ...]

# %%
import pickle

# Open and load the .pkl file
with open('./test_sets/query_galleries_HELEN.pkl', 'rb') as f:
    data = pickle.load(f)

data
# print(data.keys())
# # Print the loaded data
# for key, value in data.items():
#     print('Pose Bin: {}, Gallery Length: {}, Query Length: {}'.format(key, len(value['gallery']), len(value['query'])))
# Out:
# {'-50_-20_45_70': {'query': ['./data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_6_-0.450_0.969_-0.134.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_7_-0.489_0.877_-0.048.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_12_-0.474_1.211_-0.089.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_8_-0.353_0.987_0.102.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_12_-0.734_1.068_0.073.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_10_-0.588_1.070_-0.173.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_9_-0.410_0.962_-0.047.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_9_-0.404_1.028_-0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_10_-0.442_1.139_-0.008.jpg'],
#   'gallery': ['./data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_8_-0.383_1.143_-0.104.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_8_-0.535_1.144_-0.153.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_8_-0.557_1.143_-0.104.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_5_-0.714_0.882_-0.115.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_7_-0.633_1.056_-0.119.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_6_-0.535_0.969_-0.130.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_4_-0.711_0.794_-0.129.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_8_-0.623_1.144_-0.153.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_4_-0.537_0.795_-0.141.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_4_-0.624_0.794_-0.129.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_7_-0.355_1.056_-0.160.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_4_-0.537_0.794_-0.129.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_7_-0.720_1.056_-0.119.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_5_-0.453_0.882_-0.115.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_7_-0.458_1.056_-0.119.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_6_-0.361_0.969_-0.130.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_5_-0.627_0.882_-0.115.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_5_-0.388_0.881_-0.123.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_8_-0.470_1.143_-0.104.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_4_-0.450_0.794_-0.129.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_5_-0.737_0.881_-0.123.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_8_-0.710_1.144_-0.153.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_8_-0.448_1.144_-0.153.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_4_-0.624_0.795_-0.141.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_7_-0.529_1.056_-0.160.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_6_-0.622_0.969_-0.130.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_5_-0.365_0.882_-0.115.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_4_-0.363_0.795_-0.141.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_8_-0.361_1.144_-0.153.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_7_-0.442_1.056_-0.160.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_6_-0.624_0.969_-0.134.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_6_-0.711_0.969_-0.134.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_6_-0.537_0.969_-0.134.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_4_-0.362_0.794_-0.129.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_6_-0.362_0.969_-0.134.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_5_-0.650_0.881_-0.123.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_4_-0.450_0.795_-0.141.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_6_-0.710_0.969_-0.130.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_6_-0.448_0.969_-0.130.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_5_-0.540_0.882_-0.115.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_5_-0.475_0.881_-0.123.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_7_-0.545_1.056_-0.119.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_5_-0.563_0.881_-0.123.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_7_-0.704_1.056_-0.160.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_8_-0.644_1.143_-0.104.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_4_-0.712_0.795_-0.141.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_8_-0.732_1.143_-0.104.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_3_7_-0.617_1.056_-0.160.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2205474871/HELEN_2205474871_2_7_-0.371_1.056_-0.119.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_6_-0.442_0.789_-0.050.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_10_-0.649_0.888_0.159.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_12_-0.733_1.062_0.127.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_13_-0.564_1.149_0.122.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_13_-0.476_1.149_0.122.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_12_-0.384_1.062_0.127.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_7_-0.576_0.877_-0.048.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_10_-0.599_1.139_-0.039.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_10_-0.686_1.139_-0.039.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_9_-0.732_0.800_0.147.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_11_-0.566_0.975_0.127.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_11_-0.653_0.975_0.127.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_9_-0.470_0.800_0.147.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_10_-0.737_0.888_0.159.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_6_-0.354_0.789_-0.050.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_8_-0.436_0.964_-0.040.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_9_-0.539_1.051_-0.049.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_6_-0.529_0.789_-0.050.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_8_-0.610_0.964_-0.040.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_8_-0.785_0.964_-0.040.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_10_-0.475_0.888_0.159.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_8_-0.523_0.964_-0.040.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_13_-0.389_1.149_0.122.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_8_-0.698_0.964_-0.040.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_9_-0.383_0.800_0.147.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_9_-0.452_1.051_-0.049.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_11_-0.391_0.975_0.127.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_13_-0.738_1.149_0.122.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_9_-0.644_0.800_0.147.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_7_-0.663_0.877_-0.048.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_7_-0.751_0.877_-0.048.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_9_-0.714_1.051_-0.049.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_10_-0.388_0.888_0.159.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_7_-0.402_0.877_-0.048.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_10_-0.562_0.888_0.159.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_6_-0.703_0.789_-0.050.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_11_-0.740_0.975_0.127.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_10_-0.773_1.139_-0.039.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_9_-0.557_0.800_0.147.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_9_-0.365_1.051_-0.049.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_9_-0.627_1.051_-0.049.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_12_-0.559_1.062_0.127.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_12_-0.471_1.062_0.127.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_6_-0.616_0.789_-0.050.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_10_-0.511_1.139_-0.039.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_6_10_-0.424_1.139_-0.039.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_13_-0.651_1.149_0.122.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_11_-0.478_0.975_0.127.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2620035751/HELEN_2620035751_2_12_-0.646_1.062_0.127.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_11_-0.565_1.124_-0.084.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_9_-0.657_0.949_-0.068.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_11_-0.478_1.124_-0.084.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_12_-0.736_1.211_-0.089.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_8_-0.743_0.862_-0.071.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_8_-0.481_0.862_-0.071.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_9_-0.396_0.949_-0.068.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_8_-0.656_0.862_-0.071.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_8_-0.394_0.862_-0.071.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_11_-0.740_1.124_-0.084.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_10_-0.390_1.037_-0.091.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_12_-0.648_1.211_-0.089.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_9_-0.570_0.949_-0.068.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_11_-0.390_1.124_-0.084.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_10_-0.651_1.037_-0.091.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_10_-0.739_1.037_-0.091.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_9_-0.745_0.949_-0.068.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_8_-0.569_0.862_-0.071.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_10_-0.564_1.037_-0.091.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_11_-0.652_1.124_-0.084.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_9_-0.483_0.949_-0.068.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_12_-0.387_1.211_-0.089.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_12_-0.561_1.211_-0.089.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_1266283652/HELEN_1266283652_1_10_-0.477_1.037_-0.091.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_9_-0.685_1.074_0.118.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_8_-0.440_0.987_0.102.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_6_-0.596_0.812_0.134.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_10_-0.420_1.161_0.123.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_9_-0.598_1.074_0.118.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_7_-0.690_0.900_0.101.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_7_-0.778_0.900_0.101.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_8_-0.527_0.987_0.102.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_7_-0.603_0.900_0.101.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_8_-0.702_0.987_0.102.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_10_-0.769_1.161_0.123.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_7_-0.516_0.900_0.101.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_9_-0.510_1.074_0.118.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_9_-0.423_1.074_0.118.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_6_-0.683_0.812_0.134.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_6_-0.509_0.812_0.134.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_6_-0.422_0.812_0.134.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_10_-0.681_1.161_0.123.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_10_-0.594_1.161_0.123.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_10_-0.507_1.161_0.123.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_9_-0.772_1.074_0.118.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_8_-0.615_0.987_0.102.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_7_-0.429_0.900_0.101.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2204494382/HELEN_2204494382_2_6_-0.771_0.812_0.134.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_10_-0.488_0.894_0.079.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_12_-0.472_1.068_0.073.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_12_-0.559_1.068_0.073.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_13_-0.550_1.155_0.088.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_11_-0.478_0.981_0.072.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_12_-0.646_1.068_0.073.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_9_-0.484_0.806_0.075.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_10_-0.401_0.894_0.079.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_13_-0.375_1.155_0.088.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_10_-0.663_0.894_0.079.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_9_-0.397_0.806_0.075.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_11_-0.652_0.981_0.072.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_10_-0.576_0.894_0.079.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_13_-0.725_1.155_0.088.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_13_-0.463_1.155_0.088.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_13_-0.637_1.155_0.088.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_12_-0.385_1.068_0.073.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_11_-0.739_0.981_0.072.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_9_-0.659_0.806_0.075.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_9_-0.746_0.806_0.075.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_10_-0.750_0.894_0.079.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_11_-0.390_0.981_0.072.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_9_-0.571_0.806_0.075.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2500088309/HELEN_2500088309_2_11_-0.565_0.981_0.072.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_10_-0.501_1.070_-0.173.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_9_-0.396_0.983_-0.174.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_9_-0.570_0.983_-0.174.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_8_-0.585_0.895_-0.196.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_7_-0.480_0.808_-0.171.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_7_-0.567_0.808_-0.171.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_7_-0.654_0.808_-0.171.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_10_-0.414_1.070_-0.173.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_10_-0.675_1.070_-0.173.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_9_-0.658_0.983_-0.174.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_11_-0.732_1.157_-0.178.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_7_-0.742_0.808_-0.171.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_11_-0.558_1.157_-0.178.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_10_-0.763_1.070_-0.173.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_8_-0.498_0.895_-0.196.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_11_-0.471_1.157_-0.178.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_11_-0.383_1.157_-0.178.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_8_-0.672_0.895_-0.196.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_9_-0.483_0.983_-0.174.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_11_-0.645_1.157_-0.178.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_8_-0.411_0.895_-0.196.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_7_-0.393_0.808_-0.171.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_8_-0.760_0.895_-0.196.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2150051470/HELEN_2150051470_2_9_-0.745_0.983_-0.174.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_10_-0.400_0.991_0.253.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_9_-0.585_0.962_-0.047.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_9_-0.672_0.962_-0.047.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_12_-0.734_1.166_0.245.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_7_-0.420_0.788_-0.046.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_10_-0.749_0.991_0.253.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_11_-0.655_1.137_-0.046.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_8_-0.656_0.817_0.301.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_10_-0.493_1.050_-0.039.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_11_-0.480_1.078_0.281.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_10_-0.662_0.991_0.253.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_7_-0.508_0.788_-0.046.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_9_-0.497_0.962_-0.047.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_11_-0.393_1.078_0.281.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_11_-0.742_1.078_0.281.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_12_-0.385_1.166_0.245.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_11_-0.567_1.078_0.281.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_7_-0.595_0.788_-0.046.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_12_-0.646_1.166_0.245.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_12_-0.472_1.166_0.245.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_9_-0.479_0.904_0.219.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_11_-0.393_1.137_-0.046.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_8_-0.713_0.875_-0.042.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_8_-0.743_0.817_0.301.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_9_-0.566_0.904_0.219.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_8_-0.626_0.875_-0.042.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_10_-0.581_1.050_-0.039.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_10_-0.668_1.050_-0.039.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_11_-0.742_1.137_-0.046.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_8_-0.364_0.875_-0.042.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_12_-0.559_1.166_0.245.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_8_-0.568_0.817_0.301.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_9_-0.391_0.904_0.219.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_10_-0.574_0.991_0.253.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_10_-0.406_1.050_-0.039.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_7_-0.769_0.788_-0.046.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_9_-0.653_0.904_0.219.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_8_-0.481_0.817_0.301.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_7_-0.682_0.788_-0.046.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_8_-0.539_0.875_-0.042.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_9_-0.759_0.962_-0.047.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_8_-0.451_0.875_-0.042.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_11_-0.480_1.137_-0.046.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_9_-0.740_0.904_0.219.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_11_-0.655_1.078_0.281.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_11_-0.567_1.137_-0.046.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_10_-0.487_0.991_0.253.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_1_8_-0.394_0.817_0.301.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2005566839/HELEN_2005566839_3_10_-0.755_1.050_-0.039.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_8_-0.429_0.941_-0.119.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_8_-0.516_0.941_-0.119.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_9_-0.578_1.028_-0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_11_-0.647_1.202_-0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_10_-0.752_1.115_-0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_7_-0.359_0.853_-0.137.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_7_-0.621_0.853_-0.137.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_7_-0.446_0.853_-0.137.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_11_-0.385_1.202_-0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_7_-0.708_0.853_-0.137.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_8_-0.778_0.941_-0.119.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_10_-0.403_1.115_-0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_11_-0.560_1.202_-0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_8_-0.604_0.941_-0.119.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_9_-0.666_1.028_-0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_10_-0.665_1.115_-0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_9_-0.491_1.028_-0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_7_-0.534_0.853_-0.137.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_10_-0.578_1.115_-0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_9_-0.753_1.028_-0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_11_-0.472_1.202_-0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_11_-0.734_1.202_-0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_8_-0.691_0.941_-0.119.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_2532979343/HELEN_2532979343_2_10_-0.491_1.115_-0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_8_-0.440_0.965_-0.006.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_7_-0.615_0.877_-0.007.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_9_-0.353_1.052_-0.007.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_9_-0.615_1.052_-0.007.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_6_-0.529_0.790_-0.007.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_10_-0.354_1.139_-0.008.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_9_-0.702_1.052_-0.007.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_7_-0.702_0.877_-0.007.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_6_-0.616_0.790_-0.007.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_7_-0.440_0.877_-0.007.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_7_-0.353_0.877_-0.007.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_7_-0.527_0.877_-0.007.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_9_-0.527_1.052_-0.007.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_9_-0.440_1.052_-0.007.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_6_-0.354_0.790_-0.007.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_6_-0.441_0.790_-0.007.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_8_-0.353_0.965_-0.006.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_8_-0.615_0.965_-0.006.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_10_-0.703_1.139_-0.008.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_10_-0.616_1.139_-0.008.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_6_-0.703_0.790_-0.007.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_10_-0.529_1.139_-0.008.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_8_-0.702_0.965_-0.006.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_45_70/HELEN_221068652/HELEN_221068652_2_8_-0.527_0.965_-0.006.jpg']},
#  '-50_-20_-70_-45': {'query': ['./data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_10_-0.626_-1.105_0.079.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_8_13_-0.750_-1.220_0.075.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_1266283652/HELEN_1266283652_2_7_-0.641_-0.838_0.041.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2204494382/HELEN_2204494382_1_12_-0.379_-1.088_0.211.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2500088309/HELEN_2500088309_1_7_-0.589_-0.928_0.098.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2150051470/HELEN_2150051470_1_9_-0.509_-0.968_0.434.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2005566839/HELEN_2005566839_2_10_-0.717_-0.968_0.128.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2532979343/HELEN_2532979343_1_8_-0.687_-0.919_0.029.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_221068652/HELEN_221068652_3_12_-0.621_-1.205_-0.153.jpg'],
#   'gallery': ['./data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_8_-0.426_-0.930_0.065.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_7_-0.711_-0.843_0.059.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_11_-0.514_-1.192_0.074.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_9_-0.612_-1.018_0.060.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_9_-0.350_-1.018_0.060.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_8_-0.688_-0.930_0.065.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_8_-0.600_-0.930_0.065.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_10_-0.538_-1.105_0.079.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_9_-0.699_-1.018_0.060.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_10_-0.451_-1.105_0.079.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_11_-0.776_-1.192_0.074.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_7_-0.623_-0.843_0.059.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_11_-0.688_-1.192_0.074.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_7_-0.449_-0.843_0.059.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_9_-0.437_-1.018_0.060.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_7_-0.362_-0.843_0.059.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_10_-0.713_-1.105_0.079.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_11_-0.601_-1.192_0.074.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_8_-0.513_-0.930_0.065.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_9_-0.525_-1.018_0.060.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_10_-0.364_-1.105_0.079.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_7_-0.536_-0.843_0.059.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_8_-0.775_-0.930_0.065.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2205474871/HELEN_2205474871_1_11_-0.427_-1.192_0.074.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_5_-0.671_-0.797_0.136.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_8_-0.703_-1.059_0.115.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_5_9_-0.410_-0.791_0.125.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_8_12_-0.565_-1.132_0.059.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_8_10_-0.478_-0.958_0.059.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_5_10_-0.672_-0.878_0.162.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_8_13_-0.489_-1.220_0.075.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_5_9_-0.759_-0.791_0.125.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_9_-0.452_-1.146_0.131.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_6_-0.629_-0.884_0.167.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_8_13_-0.401_-1.220_0.075.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_7_-0.763_-0.972_0.156.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_5_12_-0.490_-1.053_0.122.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_9_-0.626_-1.146_0.131.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_5_12_-0.577_-1.053_0.122.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_6_-0.542_-0.884_0.167.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_5_13_-0.679_-1.140_0.132.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_8_-0.441_-1.059_0.115.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_7_-0.588_-0.972_0.156.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_5_13_-0.417_-1.140_0.132.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_5_10_-0.498_-0.878_0.162.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_6_-0.367_-0.884_0.167.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_5_9_-0.497_-0.791_0.125.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_9_-0.539_-1.146_0.131.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_7_-0.501_-0.972_0.156.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_8_13_-0.576_-1.220_0.075.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_8_10_-0.653_-0.958_0.059.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_8_-0.353_-1.059_0.115.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_5_-0.584_-0.797_0.136.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_8_-0.615_-1.059_0.115.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_5_11_-0.589_-0.966_0.126.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_5_11_-0.414_-0.966_0.126.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_9_-0.364_-1.146_0.131.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_8_9_-0.401_-0.871_0.069.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_8_11_-0.658_-1.045_0.058.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_8_9_-0.663_-0.871_0.069.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_6_-0.455_-0.884_0.167.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_5_11_-0.676_-0.966_0.126.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_7_5_-0.410_-0.797_0.136.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-70_-45/HELEN_2620035751/HELEN_2620035751_8_12_-0.478_-1.132_0.059.jpg',
# ...
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2500088309/HELEN_2500088309_1_4_-0.641_-0.667_0.107.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2500088309/HELEN_2500088309_1_2_-0.674_-0.492_0.106.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2500088309/HELEN_2500088309_1_5_-0.503_-0.754_0.096.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2500088309/HELEN_2500088309_1_1_-0.720_-0.405_0.083.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2500088309/HELEN_2500088309_1_0_-0.483_-0.318_0.074.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2500088309/HELEN_2500088309_1_5_-0.590_-0.754_0.096.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2500088309/HELEN_2500088309_1_0_-0.744_-0.318_0.074.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_4_-0.379_-0.531_0.409.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_5_-0.566_-0.618_0.377.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_5_-0.391_-0.618_0.377.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_3_-0.691_-0.444_0.384.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_2_-0.441_-0.357_0.398.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_6_-0.438_-0.706_0.348.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_1_-0.536_-0.269_0.325.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_6_-0.700_-0.706_0.348.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_4_-0.467_-0.531_0.409.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_1_-0.710_-0.269_0.325.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_2_-0.703_-0.357_0.398.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_3_-0.517_-0.444_0.384.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_4_-0.641_-0.531_0.409.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_2_-0.616_-0.357_0.398.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_5_-0.653_-0.618_0.377.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_2_-0.528_-0.357_0.398.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_5_-0.478_-0.618_0.377.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_2_-0.354_-0.357_0.398.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_4_-0.728_-0.531_0.409.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_3_-0.779_-0.444_0.384.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_3_-0.430_-0.444_0.384.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_6_-0.613_-0.706_0.348.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_6_-0.351_-0.706_0.348.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_3_-0.604_-0.444_0.384.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_4_-0.554_-0.531_0.409.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_5_-0.740_-0.618_0.377.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_1_-0.448_-0.269_0.325.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_6_-0.526_-0.706_0.348.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2150051470/HELEN_2150051470_1_1_-0.361_-0.269_0.325.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_2_-0.645_-0.270_0.163.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_7_-0.569_-0.706_0.130.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_7_-0.394_-0.706_0.130.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_4_-0.488_-0.445_0.162.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_5_-0.548_-0.532_0.167.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_7_-0.481_-0.706_0.130.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_4_-0.749_-0.445_0.162.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_2_-0.470_-0.270_0.163.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_3_-0.750_-0.357_0.146.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_2_-0.383_-0.270_0.163.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_3_-0.401_-0.357_0.146.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_3_-0.575_-0.357_0.146.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_5_-0.635_-0.532_0.167.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_5_-0.461_-0.532_0.167.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_7_-0.656_-0.706_0.130.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_3_-0.662_-0.357_0.146.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_2_-0.557_-0.270_0.163.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_4_-0.400_-0.445_0.162.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_2_-0.732_-0.270_0.163.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_5_-0.722_-0.532_0.167.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_7_-0.743_-0.706_0.130.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_6_-0.748_-0.619_0.132.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_6_-0.487_-0.619_0.132.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_6_-0.399_-0.619_0.132.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_6_-0.574_-0.619_0.132.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_4_-0.575_-0.445_0.162.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_3_-0.488_-0.357_0.146.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_4_-0.662_-0.445_0.162.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2005566839/HELEN_2005566839_2_6_-0.661_-0.619_0.132.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_4_-0.541_-0.570_0.021.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_1_-0.777_-0.308_0.027.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_2_-0.626_-0.396_0.027.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_3_-0.431_-0.483_0.023.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_3_-0.518_-0.483_0.023.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_3_-0.780_-0.483_0.023.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_6_-0.720_-0.745_0.029.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_3_-0.606_-0.483_0.023.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_5_-0.371_-0.657_0.025.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_6_-0.632_-0.745_0.029.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_4_-0.366_-0.570_0.021.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_4_-0.453_-0.570_0.021.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_4_-0.628_-0.570_0.021.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_1_-0.690_-0.308_0.027.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_1_-0.428_-0.308_0.027.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_5_-0.632_-0.657_0.025.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_2_-0.713_-0.396_0.027.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_1_-0.602_-0.308_0.027.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_6_-0.545_-0.745_0.029.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_5_-0.545_-0.657_0.025.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_5_-0.720_-0.657_0.025.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_5_-0.458_-0.657_0.025.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_4_-0.715_-0.570_0.021.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_2_-0.538_-0.396_0.027.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_6_-0.458_-0.745_0.029.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_6_-0.371_-0.745_0.029.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_1_-0.515_-0.308_0.027.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_2_-0.451_-0.396_0.027.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_2532979343/HELEN_2532979343_1_2_-0.364_-0.396_0.027.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_3_-0.360_-0.420_-0.146.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_7_-0.360_-0.769_-0.142.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_6_-0.445_-0.682_-0.154.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_3_-0.709_-0.420_-0.146.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_6_-0.707_-0.682_-0.154.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_6_-0.358_-0.682_-0.154.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_2_-0.361_-0.333_-0.132.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_3_-0.534_-0.420_-0.146.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_7_-0.621_-0.769_-0.142.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_4_-0.447_-0.507_-0.190.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_4_-0.709_-0.507_-0.190.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_2_-0.710_-0.333_-0.132.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_2_-0.448_-0.333_-0.132.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_6_-0.532_-0.682_-0.154.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_5_-0.360_-0.595_-0.153.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_4_-0.360_-0.507_-0.190.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_5_-0.622_-0.595_-0.153.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_7_-0.447_-0.769_-0.142.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_3_-0.447_-0.420_-0.146.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_3_-0.622_-0.420_-0.146.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_4_-0.534_-0.507_-0.190.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_6_-0.620_-0.682_-0.154.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_5_-0.535_-0.595_-0.153.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_2_-0.535_-0.333_-0.132.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_7_-0.534_-0.769_-0.142.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_5_-0.448_-0.595_-0.153.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_5_-0.709_-0.595_-0.153.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_2_-0.622_-0.333_-0.132.jpg',
#    './data/300WLPA_2d/HELEN_test_bins_rad2degrees/-50_-20_-45_-15/HELEN_221068652/HELEN_221068652_3_7_-0.709_-0.769_-0.142.jpg']}}

# %%
def Transfer_Folders(source_path, dest_path)
    for root, dirs, files in os.walk(source_path, topdown= True):
    #     print(dirs)
        if len(dirs) == 0:
            ID = root.split('/')[-1]
            print(ID)
            file_path = os.path.join(dest_path, ID)
            os.makedirs(file_path, exist_ok= True)
            
            for file in files:
                img_path = os.path.join(root, file)
                face = RetinaFace.extract_faces(img_path= img_path, align= True, allow_upscaling= False)
                if len(face) > 0:
                    face = Image.fromarray(face[0])
                    face = face.convert("RGB")
                    plt.imshow(face)
                    plt.show(face)
                    print("Detected")
                    save_path = os.path.join(file_path, file)
                    face.save(save_path) 
                    print(save_path)
                else:
                    img = Image.open(img_path)
                    plt.imshow(img)
                    plt.show()
                    print("Not Detected or already cropped")
                    save_path = os.path.join(file_path, file)
                    print(save_path)
                    img.save(save_path)
# Transfer_Folders()

# %%
def convertImages(root_dir):
    # Convert .pgm files to .jpeg
    for root, dirs, files in os.walk(root_dir, topdown= True):
        
        for file in files:
            print(file)
            if "pgm" in file:
                filename = file
                file_path = root + "/" + filename
                img = Image.open(file_path)
                os.remove(file_path)
                img.save(file_path.replace('.pgm', '.jpeg'))
# convertImages("./P1E")

# %%
def Merge_Sets(main_folder, dest_folder):

    # Get the list of camera angle subfolders
    camera_folders = [folder for folder in os.listdir(main_folder)]
    os.makedirs(os.path.join(main_folder, dest_folder), exist_ok= True)
    # Iterate over camera angle subfolders
    for camera_folder in camera_folders:
        # Set the path to the camera angle subfolder
        camera_folder_path = os.path.join(main_folder, camera_folder)
        
        # Get the list of identity subfolders in the camera angle subfolder
        identity_folders = [folder for folder in os.listdir(camera_folder_path)]
        
        # Iterate over identity subfolders
        for identity_folder in identity_folders:
            # Set the path to the identity subfolder
            identity_folder_path = os.path.join(camera_folder_path, identity_folder)
            
            # Set the destination folder path (where all identity folders will be merged)
            destination_folder_path = os.path.join(main_folder, dest_folder, identity_folder)
            
            # Create the destination folder if it doesn't exist
            os.makedirs(destination_folder_path, exist_ok=True)
            
            # Get the list of image files in the identity subfolder
            image_files = [file for file in os.listdir(identity_folder_path) if file.endswith(".jpeg")]
            
            # Move each image file to the destination folder
            for image_file in image_files:

                source_file_path = os.path.join(identity_folder_path, image_file)
                destination_file_path = os.path.join(destination_folder_path, image_file)
                base_name, extension = os.path.splitext(image_file)
                if (os.path.exists(destination_file_path)):
                    count = 1
                    while True:
                        new_base_name = f"{base_name}_{str(count).zfill(2)}"
                        new_file_name = f"{new_base_name}{extension}"
                        new_destination_file_path = os.path.join(destination_folder_path, new_file_name)
                        if not os.path.exists(new_destination_file_path):
                            destination_file_path = new_destination_file_path
                            break
                        count += 1
                
                shutil.copy(source_file_path, destination_file_path)
# Merge_Sets("./P1E/", "P1E_Merge")

# %%
source_path= './data/AFW/AFW_aligned'
for root, dirs, files in os.walk(source_path, topdown= True):
    print

# %%
# Clean images by deploying RetinaFace
def DetectAndAlign(root_directory_path):

    # Walk from the root directory and replace every image in each subdirectory with their image in the subdirectory.
    for root, dirs, files in os.walk(root_directory_path, topdown= True):
        # Go through each file and conduct facial detection and alignment
        for file in files:
            if "jpg" in file:
                file_path = os.path.join(root, file)
                face = RetinaFace.extract_faces(img_path= file_path, align= True, allow_upscaling= False)
                if len(face) > 0:
                    face = Image.fromarray(face[0])
                    face = face.convert("RGB")
                    print("Detected " + file)
                    # plt.imshow(face)
                    # plt.show(face)
                    os.remove(file_path)
                    face.save(file_path)
                else:
                    print("Not Detected " + file )
          
        

dir_path = "./data/300WLPA_2d/AFW_not_detected/"
DetectAndAlign(dir_path)

# %%
for root, dirs, files in os.walk("./QMUL-SurvFace/small_train_set/", topdown= True):
        # Go through each file and conduct facial detection and alignment
        for file in files:
            if "cam" in file:
                print(root)
                img = cv2.imread(root + "/" + file) 
                print("{}, {}, {}".format(img.shape[2], img.shape[0], img.shape[1]))

# %%
for root, dirs, files in os.walk("./data/300WLPA_2d/LFPW_detected", topdown= False):
        # Go through each file and conduct facial detection and alignment
        if len(files) == 0 and len(dirs) == 0:
                print(root)
                os.rmdir(root)

# %%
for root, dirs, files in os.walk("./data/300WLPA_2d/AFW_not_detected", topdown= False):
        # Go through each file and conduct facial detection and alignment
        if len(dirs) == 0:
            for file in files:
                source_path = os.path.join(root, file)
                print(source_path)
                dst_path = os.path.join(os.path.relpath())

# %%
# Removes the depth files from the MAPIR Dataset
def Remove_Files(root_dir):
    for root, dirs, files in os.walk(root_dir, topdown= True):
        print(files)
        for file in files:
            if "_" in file:
                os.remove(os.path.join(root, file))
root_dir = "./cplfw/"
Remove_Files(root_dir)

# %%
# Counts images per each identity as well as the total number of images
def count_file(root_dir):
    total_count_file = 0
    # folder_count = 0
    for folder_name in os.listdir(root_dir):
        sub_dir = os.path.join(root_dir, folder_name)
        total_count = 0
        folder_count = 0
        for root, dirs, files in os.walk(sub_dir, topdown= True):
            count = 0
            folder_count += 1
            for file in files:
                total_count += 1
                total_count_file += 1
                count += 1

        # print(f'{folder_name} images: {total_count}')
        print(f'{folder_name} identities: {folder_count}, count: {total_count}')
    print(f'Total images: {total_count_file}')
count_file(root_dir="./data/300WLPA_2d/HELEN_test_bins_rad2degrees")
# Out:
# -50_-20_45_70 identities: 127, count: 3142
# -50_-20_-70_-45 identities: 159, count: 3891
# -20_50_-90_-70 identities: 175, count: 2761
# -20_50_15_45 identities: 172, count: 4187
# -50_-20_-15_15 identities: 194, count: 2254
# -50_-20_15_45 identities: 127, count: 3501
# -20_50_45_70 identities: 170, count: 3865
# -20_50_-45_-15 identities: 179, count: 3945
# -20_50_-15_15 identities: 228, count: 2223
# -50_-20_70_90 identities: 127, count: 2429
# -20_50_70_90 identities: 170, count: 3032
# -20_50_-70_-45 identities: 178, count: 3491
# -50_-20_-90_-70 identities: 159, count: 3042
# -50_-20_-45_-15 identities: 159, count: 4510
# Total images: 46273

# %%
class LFWDataset(torch.utils.data.Dataset):
    def __init__(self, root_dir, transform= None):
        self.root_dir = root_dir
        self.data = []
        self.labels = []
        self.transform = transform
        for label, subdir in enumerate(os.listdir(root_dir)):
            subdir_path = os.path.join(root_dir, subdir)
            if not os.path.isdir(subdir_path):
                continue
            for img_file in os.listdir(subdir_path):
                img_path = os.path.join(subdir_path, img_file)
                self.data.append(img_path)
                self.labels.append(label)

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        img_path = self.data[idx]
        img = Image.open(img_path).convert("RGB")
        if (self.transform is not None):
            img = self.transform(img)
        label = self.labels[idx]
        return img, label

# %%
LPA_D = torchvision.datasets.ImageFolder(root= "./data/300WLPA_2d/AFW", transform= transform_pose)
num_classes = len(set(LPA_D.classes))

# %%
# data_loader_valid = DataLoader(lfwdataset_val, batch_size= 32, shuffle= False, num_workers=0, collate_fn= None, pin_memory= True)
# data_loader_train = DataLoader(lfwdataset_train, batch_size= 32, shuffle= True, num_workers=0, collate_fn= None, pin_memory= True)
# data_loader_test = DataLoader(lfwdataset_test, batch_size= 32, shuffle= False, num_workers=0, collate_fn= None, pin_memory= False)

# num_classes = len(set(lfwdataset_train.labels))
# img, label = lfwdataset_train[0]
# print(lfwdataset_train.data)
# print(lfwdataset_train.labels)
# plt.imshow(img.permute(1,2,0))
# plt.show()

# #num_classes = len(set(lfwdataset_val.labels))
# print(len(set(lfwdataset_test)))
# print(len(set(lfwdataset_train.labels)))
# print(len(set(lfwdataset_test.labels)))
# print(len(set(lfwdataset_val.labels)))

# %%
# Instantiate HopeNet
pose_estimator = Hopenet(torchvision.models.resnet.Bottleneck, [3, 4, 6, 3], 66)
pose_estimator.load_state_dict(torch.load("./models/deepheadpose/hopenet_robust_alpha1.pkl", map_location= device))
pose_estimator.to(device)
pose_estimator.eval()

# %% [markdown]
# ### Test Hopenet for a single image

# %%
img, label = LPA_D[21]
print(LPA_D.samples[21])
# faces = RetinaFace.extract_faces(img_path= "./MAPIR-Faces-Dataset/001/image_3-0_rgb.png")
# faces = Image.fromarray(faces[0])
# faces.convert("RGB")
# faces = transform_pose(faces)
# img = faces
img = torch.unsqueeze(img, dim=0).to(device)
print(img.shape)
# print(label)
yaw, pitch, roll = pose_estimator(img)
img = torch.squeeze(img, dim= 0).to("cpu")
plt.imshow(img.permute(1,2,0))
plt.show()
print('yaw: {}, pitch: {}, roll: {}'.format(yaw, pitch, roll))
print(yaw.shape)

# %%
 # Binned predictions
_, yaw_bpred = torch.max(yaw.data, 1)
_, pitch_bpred = torch.max(pitch.data, 1)
_, roll_bpred = torch.max(roll.data, 1)

print(yaw_bpred)

# %%
idx_tensor = [idx for idx in range(66)]
idx_tensor = torch.FloatTensor(idx_tensor).to(device)
# Continuous predictions
yaw_predicted = softmax_temperature(yaw.data, 1)
pitch_predicted = softmax_temperature(pitch.data, 1)
roll_predicted = softmax_temperature(roll.data, 1)

# Get continuous predictions in degrees.
yaw_predicted = torch.sum(yaw_predicted.data[0] * idx_tensor) * 3 - 99
pitch_predicted = torch.sum(pitch_predicted.data[0] * idx_tensor) * 3 - 99
roll_predicted = torch.sum(roll_predicted.data[0] * idx_tensor) * 3 - 99

print(roll_predicted)
print(yaw_predicted)
print(pitch_predicted)

# %% [markdown]
# ## Estimate Poses of Every image in the dataset

# %%
# Estimate the Pitch and Yaw of every image in the MAPIR Dataset
pitch_list = []
yaw_list = []

img_poses = {}
for idx, (img, label) in enumerate(LPA_D):
    img = torch.unsqueeze(img, dim=0).to(device)
    yaw, pitch, roll = pose_estimator(img)
    
    idx_tensor = [idx for idx in range(66)]
    idx_tensor = torch.FloatTensor(idx_tensor).to(device)
    # Continuous predictions
    yaw_predicted = softmax_temperature(yaw.data, 1)
    pitch_predicted = softmax_temperature(pitch.data, 1)
    roll_predicted = softmax_temperature(roll.data, 1)

    # Get continuous predictions in degrees.
    yaw_predicted = torch.sum(yaw_predicted.data[0] * idx_tensor) * 3 - 99
    pitch_predicted = torch.sum(pitch_predicted.data[0] * idx_tensor) * 3 - 99
    roll_predicted = torch.sum(roll_predicted.data[0] * idx_tensor) * 3 - 99

    img_poses[LPA_D[idx]] = (pitch_predicted.to("cpu").numpy(), yaw_predicted.to("cpu").numpy(), idx)
    pitch_list.append(pitch_predicted.to("cpu").numpy())
    yaw_list.append(yaw_predicted.to("cpu").numpy())

    print("Pitch: {}, Yaw: {}".format(pitch_predicted, yaw_predicted))

# %% [markdown]
# ## Display the pose distribution of the current dataset

# %%
# Create a figure and axes for the plot
fig, ax = plt.subplots()
# Create histograms
ax.hist(pitch_list, bins=50, alpha=0.5, label='Pitch')
ax.hist(yaw_list, bins=50, alpha=0.5, label='yaw')

# Set labels and title
ax.set_xlabel('Angles')
ax.set_ylabel('Frequency')
ax.set_title('Distribution of Pitch and Yaw Angles')

# Add a legend
ax.legend()

# Display the plot
plt.show()

# Show the plot
plt.show()

# %%
count = 0 
identity_count = {}
for img_path, (pitch, yaw, data_idx) in img_poses.items():
    img, label = SurvFace_dataset_estimate[data_idx]
    if (pitch < 25 and pitch > -25) and (yaw < 25 and yaw > -25):
        count += 1 
        if (label not in identity_count):
            identity_count[label] = 1
        else:
            identity_count[label] += 1
for label, val in identity_count.items():
    print("{}: {}".format(label, val))
print("Total images in pose bin {}".format(count))

# %% [markdown]
# ## Crop and Align Face, Estimate pose, and put the images in a folder bin labeled with the estimated pose range
# # Iterate through a set of images -> crop & align faces -> Estimate pose -> Verify acceptable pose range -> Save Image in a folder under its name

# %%
# Get a set of images
def Get_Pose_Bin(img_path, dest_path, yaw_range, pitch_range):
    
    # Define the ranges for the pitch and yaw pose bins
    yaw_min, yaw_max = yaw_range
    pitch_min, pitch_max = pitch_range
    
    # Make directory if path exists
    os.makedirs(dest_path, exist_ok= True)

    # Make a new folder for pose bins and organize each image by class folder 
    for root, dirs, files in os.walk(img_path, topdown= True):
        if len(dirs) == 0: 
            ID = root.split('/')[-1]
            # file_path = os.path.join(dest_path, ID)
            # os.makedirs(file_path, exist_ok= True)
            for file in files:
                if "jpg" in file:

                    # Open image path and convert to tensor 
                    img_path = os.path.join(root, file)
                    img = Image.open(img_path)
                    img = transform_pose(img)
                    img = torch.unsqueeze(img, dim= 0).to("mps")

                    # Pass Tensor to HopeNet Pose estimator
                    yaw, pitch, roll = pose_estimator(img)
                    
                    idx_tensor = [idx for idx in range(66)]
                    idx_tensor = torch.FloatTensor(idx_tensor).to(device)
                    # Continuous predictions
                    yaw_predicted = softmax_temperature(yaw.data, 1)
                    pitch_predicted = softmax_temperature(pitch.data, 1)
                    roll_predicted = softmax_temperature(roll.data, 1)

                    # Get continuous predictions in degrees.
                    yaw_predicted = torch.sum(yaw_predicted.data[0] * idx_tensor) * 3 - 99
                    pitch_predicted = torch.sum(pitch_predicted.data[0] * idx_tensor) * 3 - 99

                    
                    # Check if image is within desired bin range 
                    # if frontal == True:
                    if (yaw_predicted > yaw_min) and (yaw_predicted < yaw_max) and (pitch_predicted > pitch_min) and (pitch_predicted < pitch_max):
                        file_dest_path = os.path.join(dest_path, ID)
                        file_source_path = os.path.join(root, file)
                        print("Yaw: {}".format(yaw_predicted))
                        print("Pitch: {}".format(pitch_predicted))
                        
                        os.makedirs(file_dest_path, exist_ok= True)
                        shutil.copy(file_source_path, file_dest_path)
                    # else:
                    #     if (yaw_predicted < yaw_min) or (yaw_predicted > yaw_max) :
                    #         file_dest_path = os.path.join(dest_path, ID)
                    #         file_source_path = os.path.join(root, file)
                    #         print("Yaw Non-frontal: {}".format(yaw_predicted))
                    #         os.makedirs(file_dest_path, exist_ok= True)
                    #         shutil.copy(file_source_path, file_dest_path)
                    
Get_Pose_Bin("./data/300WLPA_2d/AFW_aligned/", "/data/300WLPA_2d/AFW_aligned_-30_15_-30_30/", yaw_range=(-30, 30), pitch_range= (-30, 15))

# %%
#Implemenet CNN Baacosh_ckbone
Path_resnet = Path('./arcface_weights_kaggle/QMUL_weights/frontal/resnet50_weights_frontal_survface_epoch_330.pth') 
if (Path_resnet.is_file()):
    models = iresnet50(pretrained=True)
    models.fc.requires_grad = True
#     models = DataParallel(models)
    models.load_state_dict(torch.load('./arcface_weights_kaggle/QMUL_weights/frontal/resnet50_weights_frontal_survface_epoch_330.pth', map_location= 'mps'))
    # models.load_state_dict(torch.load('/Users/carterung/CV_Research/arcface_weights_kaggle/resnet50_weights3.pth', map_location= device))
    print('weights loaded')
else:
    models = iresnet50(pretrained= True)
    for param in models.parameters():
        param.requires_grad_(False)
    models.fc.requires_grad_(True)
    models.to(device)

models.to(device)
models

# %%
Path_arcface = Path('./arcface_weights_kaggle/QMUL_weights/frontal/arcface_weights_frontal_survface_epoch_330.pth')

if (Path_arcface.is_file()):
    metric_fc = ArcFaceLoss(512, num_classes, 64.0, 0.5)
    # metric_fc = DataParallel(metric_fc)
    metric_fc.requires_grad = True
    metric_fc.load_state_dict(torch.load('./arcface_weights_kaggle/QMUL_weights/frontal/arcface_weights_frontal_survface_epoch_330.pth', map_location= torch.device("mps")))
else:
    metric_fc = ArcFaceLoss(512, num_classes, 64.0, 0.5)
    # metric_fc = DataParallel(metric_fc)
    metric_fc.requires_grad = True

metric_fc.to(device)
print(metric_fc.state_dict())

# Analyze model parameters and layers
#summary(models, (3, 112, 112))

# %% [markdown]
# ### Code for Inference Evaluation and Calculations

# %%
PATH = "/Users/carterung/CV_Research/arcface_weights_kaggle/QMUL_weights/frontal/frontal_epoch=249-step=16750.ckpt"
models = models.load_state_dict(torch.load('./', map_location= device))

# %%
# Get the embedding list and label list
with torch.no_grad():
    models.eval()
    embedding_list = []
    label_list = []
    # Fill query and gallery set
    for i, (img, label) in enumerate(data_loader_test):
        img, label = img.to(device), label.to(device)
        embeddings = models(img)
        embedding_list.append(embeddings)
        label_list.append(label)

    label_list = torch.cat(label_list)
    embedding_list = torch.cat(embedding_list)

# %%
# Make class dictionary
class_dict = {}
label_list = label_list.to("cpu").numpy().tolist()
for i in range(len(label_list)):
    if (label_list[i] not in class_dict):
        class_dict[label_list[i]] = [embedding_list[i]]
    else:
        class_dict[label_list[i]].append(embedding_list[i])

# %%
for label in class_dict.keys():
    class_dict[label] = torch.stack(class_dict[label])

# %%
# Fill query and gallery sets
query_set = {"embedding": [],
            "label": []}
gallery_set = {"embedding": [],
            "label": []}
for label in class_dict.keys():
    if (len(class_dict[label]) > 1):
        query_set["embedding"].append(class_dict[label][0])
        query_set["label"].append(label)
        
        for j in range(1, len(class_dict[label])):
            gallery_set["embedding"].append(class_dict[label][j])
            gallery_set["label"].append(label)

# %%
gallery_set["embedding"] = torch.stack(gallery_set["embedding"])
label_dict = {}
for idx in range(len(gallery_set["label"])):
    label_dict[idx] = gallery_set["label"][idx]
gallery_set["label"] = label_dict   

print(len(gallery_set["label"]))
print(len(query_set["embedding"]))
print(gallery_set["embedding"].shape)
print(query_set["embedding"][0].shape)

# %%
# Probe images to test against the embedding gallery
with torch.inference_mode():
    models.eval()
    correct_counts = [0.0] * len(gallery_set["label"])
    total_counts = [0.0] * len(gallery_set["label"])
    top_k_accuracy = [0.0] * len(gallery_set["label"])

    for probe_idx in range(len(query_set['embedding'])):
        probe_emb = query_set['embedding'][probe_idx]
        probe_label = query_set['label'][probe_idx]
        cos_similarity = F.cosine_similarity(probe_emb, gallery_set['embedding'], dim= -1)

        # Iterate over all values of k
        for k in range(1, len(gallery_set["label"]) + 1):
            ret, pred = torch.topk(cos_similarity, k)
            # Compute accuracy for this value of k
            correct_counts[k-1] += int(any(probe_label == gallery_set['label'][i] for i in pred.to("cpu").numpy().tolist()[:k]))
            total_counts[k-1] += 1
            top_k_accuracy[k-1] = correct_counts[k-1] / total_counts[k-1]

# Plot the accuracy vs top-k rank
import matplotlib.pyplot as plt
print("Rank 1 Accuracy: {}, Rank 5 Accuracy: {}".format(top_k_accuracy[0], top_k_accuracy[4]))
plt.plot(range(1, len(top_k_accuracy)+1), top_k_accuracy)
plt.xlabel('Top-k rank')
plt.ylabel('Accuracy')
plt.show()

# %%
models = torchvision.models.resnet50(pretrained=True)
# Evaluate against my model 
with torch.inference_mode():
    correct_count = 0.0
    models.eval()
    # metric_fc.eval()
    y_true = []
    y_pred = []
    cos_list_same = []
    cos_list_diff = []
    cos_list = []
    models.to("cpu")
  
    for idx, (img1, img2, label) in enumerate(lfw_pairs_test):
    # for idx in range(600, len(lfw_pairs_test)):
        # Do Face Detection Alignment
        # label = 0
     
        img1_path, img2_path = lfw_pairs_test.data[idx]
        faces1 = RetinaFace.extract_faces(img1_path, align= True, allow_upscaling= True)
        faces2 = RetinaFace.extract_faces(img2_path, align= True, allow_upscaling= True)
        
        max_cos_sim = -50
        # Find the most prominent matches in the images
        for i in range(len(faces1)):
            img1 = Image.fromarray(faces1[i])
            img1 = img1.convert("RGB")
            img1 = transform(img1)
            
            img1.to(device)
            img1 = torch.unsqueeze(img1, dim= 0)
            embed_1 = models(img1)
            
            for j in range(len(faces2)):
                img2 = Image.fromarray(faces2[j])
                img2 = img2.convert("RGB")
                img2 = transform(img2)

                img2.to(device)
                img2 = torch.unsqueeze(img2, dim= 0)
                embed_2 = models(img2)
                face_cos_sim = F.cosine_similarity(embed_1, embed_2)
                if (face_cos_sim > max_cos_sim):
                    max_cos_sim = face_cos_sim
                    main_img1 = img1
                    main_img2 = img2
                    
        
        # fig = plt.figure()
        # ax1 = fig.add_subplot(2, 2, 1)
        # ax1.imshow(main_img1.squeeze().permute(1,2,0))
        # ax2 = fig.add_subplot(2, 2, 2)
        # ax2.imshow(main_img2.squeeze().permute(1,2,0))
        # plt.show()

        cos_sim = max_cos_sim
        cos_list.append(cos_sim.to("cpu"))
        if (label == 1):
            cos_list_same.append(cos_sim.to("cpu"))
        else:
            cos_list_diff.append(cos_sim.to("cpu"))
            
        print('Cosine Similarity: {}, Prediction: {}, Ground Truth: {}'.format(cos_sim.to("cpu").numpy()[0], cos_sim.to("cpu").numpy()[0] > 0.313, label))
        correct_count += label == (cos_sim.to("cpu").numpy()[0] > 0.313)
        
        # Add labels and predictions
        y_true.append(label)
        y_pred.append(cos_sim.to("cpu").numpy()[0] > 0.313)

    print(correct_count / len(lfw_pairs_test))

# %%
# Make Confusion Matrix
cm = confusion_matrix(y_true, y_pred)

# Display Matrix
cm_display = ConfusionMatrixDisplay(cm).plot()

# %%
# Compute a histogram of true and false labels for cosine similarity
verification_scores_same = np.array([score.item() for score in cos_list_same])
verification_scores_diff = np.array([score.item() for score in cos_list_diff])
verification_scores = np.array([score.item() for score in cos_list])


# Create histograms
plt.hist(verification_scores_same, bins=50, alpha=0.5, label='Same Person')
plt.hist(verification_scores_diff, bins=50, alpha=0.5, label='Different Person')

# Add legend, labels, and title
plt.legend(loc='upper right')
plt.xlabel('Verification score')
plt.ylabel('Frequency')
plt.title('Histograms of face verification scores')

# Show the plot
plt.show()

# %%
# Make Graph and Histogram of Data Distributions
plt.plot(y_true, cos_list, 'bo', markersize=.018)
plt.ylabel('Cos_similarity')
plt.xlabel('Label')
plt.show()

# %%
from deepface import DeepFace
models.eval()
models.to(device)

PATHOne= '/Users/carterung/CV_Research/QMUL-SurvFace/Face_Verification_Test_Set/verification_images/15_cam3_1.jpg'
PATHTwo= '/Users/carterung/CV_Research/QMUL-SurvFace/Face_Verification_Test_Set/verification_images/25_cam3_1.jpg'
Carter_Pic1_Path = PATHOne
Carter_Pic2_Path = PATHTwo


Carter_Pic1 = Image.open(PATHOne)
Carter_Pic2 = Image.open(PATHTwo)
Carter_Pic1 = transform(Carter_Pic1)
Carter_Pic2 = transform(Carter_Pic2)

fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax1.imshow(Carter_Pic1.permute(1,2,0))
ax2 = fig.add_subplot(2, 2, 2)
ax2.imshow(Carter_Pic2.permute(1,2,0))
plt.show()


Carter_Pic1, Carter_Pic2 = Carter_Pic1.to(device), Carter_Pic2.to(device)
Carter_Pic1 = torch.unsqueeze(Carter_Pic1, dim= 0)
Carter_Pic2 = torch.unsqueeze(Carter_Pic2, dim= 0)
emb_1 = models(Carter_Pic1)
emb_2 = models(Carter_Pic2)
cosine_sim = F.cosine_similarity(emb_1, emb_2)
obj = DeepFace.verify(Carter_Pic1_Path, Carter_Pic2_Path
          , model_name = 'ArcFace', detector_backend = 'skip')
print('DeepFace Result: {}'.format(1 - obj['distance']))
print('My Model: {}'.format(cosine_sim))
Img_T1 = Image.open(PATHOne)
Img_T2 = Image.open(PATHTwo)
fig = plt.figure()
ax1 = fig.add_subplot(2, 2, 1)
ax1.imshow(Img_T1)
ax2 = fig.add_subplot(2, 2, 2)
ax2.imshow(Img_T2)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[16], line 2
#       1 from deepface import DeepFace
# ----> 2 models.eval()
#       3 models.to(device)
#       5 PATHOne= '/Users/carterung/CV_Research/QMUL-SurvFace/Face_Verification_Test_Set/verification_images/15_cam3_1.jpg'
#
# NameError: name 'models' is not defined
